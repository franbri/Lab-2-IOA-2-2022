# %%
from main import tabu
bestSolution, bestCost, allCosts = tabu("cap41", 50)
# Out:
# tamaño lista tabu 2
# iteracion numero: 0
# tamaño lista tabu 3
# iteracion numero: 1
# tamaño lista tabu 4
# iteracion numero: 2
# tamaño lista tabu 5
# iteracion numero: 3
# tamaño lista tabu 6
# iteracion numero: 4
# tamaño lista tabu 7
# iteracion numero: 5
# tamaño lista tabu 8
# iteracion numero: 6
# tamaño lista tabu 9
# iteracion numero: 7
# tamaño lista tabu 10
# iteracion numero: 8
# tamaño lista tabu 11
# iteracion numero: 9
# tamaño lista tabu 12
# iteracion numero: 10
# tamaño lista tabu 13
# iteracion numero: 11
# tamaño lista tabu 14
# iteracion numero: 12
# tamaño lista tabu 15
# iteracion numero: 13
# tamaño lista tabu 16
# iteracion numero: 14
# tamaño lista tabu 17
# iteracion numero: 15
# tamaño lista tabu 18
# iteracion numero: 16
# tamaño lista tabu 19
# iteracion numero: 17
# tamaño lista tabu 20
# iteracion numero: 18
# tamaño lista tabu 21
# iteracion numero: 19
# tamaño lista tabu 22
# iteracion numero: 20
# tamaño lista tabu 23
# iteracion numero: 21
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(allCosts)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
